# %%
import pandas as pd

acute = pd.read_csv('ahb_cleaned.csv')
chronic = pd.read_csv('chbae_cleaned.csv')

# %%
from hepatitis_modules import heatmap_pipeline

heatmap_pipeline.fit_transform(acute)

# %%
heatmap_pipeline.fit_transform(chronic, heatmap__acute=False)
